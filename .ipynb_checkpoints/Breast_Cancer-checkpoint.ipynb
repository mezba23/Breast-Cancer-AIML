# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np

# %%
import pandas as pd
path="/content/drive/MyDrive/Colab Notebooks/data.csv"
df=pd.read_csv(path)
df
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
df.drop("Unnamed: 32",axis=1,inplace=True)
df
# Out:
#            id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0      842302         M  ...          0.4601                  0.11890
# 1      842517         M  ...          0.2750                  0.08902
# 2    84300903         M  ...          0.3613                  0.08758
# 3    84348301         M  ...          0.6638                  0.17300
# 4    84358402         M  ...          0.2364                  0.07678
# ..        ...       ...  ...             ...                      ...
# 564    926424         M  ...          0.2060                  0.07115
# 565    926682         M  ...          0.2572                  0.06637
# 566    926954         M  ...          0.2218                  0.07820
# 567    927241         M  ...          0.4087                  0.12400
# 568     92751         B  ...          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
X=df.drop("diagnosis",axis=1)
y=df["diagnosis"]

# %%
X
# Out:
#            id  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0      842302        17.99  ...          0.4601                  0.11890
# 1      842517        20.57  ...          0.2750                  0.08902
# 2    84300903        19.69  ...          0.3613                  0.08758
# 3    84348301        11.42  ...          0.6638                  0.17300
# 4    84358402        20.29  ...          0.2364                  0.07678
# ..        ...          ...  ...             ...                      ...
# 564    926424        21.56  ...          0.2060                  0.07115
# 565    926682        20.13  ...          0.2572                  0.06637
# 566    926954        16.60  ...          0.2218                  0.07820
# 567    927241        20.60  ...          0.4087                  0.12400
# 568     92751         7.76  ...          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier
model= RandomForestClassifier()
model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
model.fit(x_train,y_train);

# %%
x_train
# Out:
#            id  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 178    873357        13.01  ...          0.2295                  0.05843
# 44   85638502        13.17  ...          0.3693                  0.09618
# 383     90251        12.39  ...          0.2819                  0.11180
# 274   8911163        17.93  ...          0.2504                  0.07948
# 336    897604        12.99  ...          0.2432                  0.10090
# ..        ...          ...  ...             ...                      ...
# 106    863031        11.64  ...          0.2806                  0.09097
# 52     857374        11.94  ...          0.2785                  0.07408
# 409    905501        12.27  ...          0.3455                  0.06896
# 515    916221        11.34  ...          0.3060                  0.06783
# 99     862548        14.42  ...          0.2718                  0.09353
#
# [455 rows x 31 columns]

# %%
y_preds=model.predict(x_test)
y_preds
# Out:
# array(['M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B',
#        'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'M',
#        'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M'], dtype=object)

# %%
y_test
# Out:
# 28     M
# 538    B
# 330    M
# 508    B
# 281    B
#       ..
# 553    B
# 14     M
# 363    B
# 454    B
# 230    M
# Name: diagnosis, Length: 114, dtype: object

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
model.score(x_test,y_test)
# Out:
# 0.956140350877193

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
print(classification_report(y_test,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.97      0.96      0.97        79
#            M       0.92      0.94      0.93        35
#
#     accuracy                           0.96       114
#    macro avg       0.95      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
confusion_matrix(y_test,y_preds)
# Out:
# array([[76,  3],
#        [ 2, 33]])

# %%
accuracy_score(y_test,y_preds)
# Out:
# 0.956140350877193

# %%
np.random.seed(69)
for i in range (10,100,10):
  print(f"trying model with {i} estimators")
  model=RandomForestClassifier(n_estimators=i).fit(x_train,y_train)
  percentage=model.score(x_test,y_test)
  print(f"model accuracy on test set:{percentage}")
  print("")
# Out:
# trying model with 10 estimators
# model accuracy on test set:0.9385964912280702
#
# trying model with 20 estimators
# model accuracy on test set:0.9473684210526315
#
# trying model with 30 estimators
# model accuracy on test set:0.956140350877193
#
# trying model with 40 estimators
# model accuracy on test set:0.9649122807017544
#
# trying model with 50 estimators
# model accuracy on test set:0.9649122807017544
#
# trying model with 60 estimators
# model accuracy on test set:0.9649122807017544
#
# trying model with 70 estimators
# model accuracy on test set:0.956140350877193
#
# trying model with 80 estimators
# model accuracy on test set:0.9649122807017544
#
# trying model with 90 estimators
# model accuracy on test set:0.956140350877193
