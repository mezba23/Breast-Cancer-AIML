# %%
import numpy as np

# %%
import pandas as pd
path="data.csv"
df=pd.read_csv(path)
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
df.drop("Unnamed: 32",axis=1,inplace=True)
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0    ...        25.380          17.33           184.60      2019.0
# 1    ...        24.990          23.41           158.80      1956.0
# 2    ...        23.570          25.53           152.50      1709.0
# 3    ...        14.910          26.50            98.87       567.7
# 4    ...        22.540          16.67           152.20      1575.0
# ..   ...           ...            ...              ...         ...
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
X=df.drop("diagnosis",axis=1)
y=df["diagnosis"]

# %%
X
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302        17.99         10.38          122.80     1001.0
# 1      842517        20.57         17.77          132.90     1326.0
# 2    84300903        19.69         21.25          130.00     1203.0
# 3    84348301        11.42         20.38           77.58      386.1
# 4    84358402        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564    926424        21.56         22.39          142.00     1479.0
# 565    926682        20.13         28.25          131.20     1261.0
# 566    926954        16.60         28.08          108.30      858.1
# 567    927241        20.60         29.33          140.10     1265.0
# 568     92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0           0.2419  ...        25.380          17.33           184.60
# 1           0.1812  ...        24.990          23.41           158.80
# 2           0.2069  ...        23.570          25.53           152.50
# 3           0.2597  ...        14.910          26.50            98.87
# 4           0.1809  ...        22.540          16.67           152.20
# ..             ...  ...           ...            ...              ...
# 564         0.1726  ...        25.450          26.40           166.10
# 565         0.1752  ...        23.690          38.25           155.00
# 566         0.1590  ...        18.980          34.12           126.70
# 567         0.2397  ...        25.740          39.42           184.60
# 568         0.1587  ...         9.456          30.37            59.16
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0        2019.0           0.16220            0.66560           0.7119
# 1        1956.0           0.12380            0.18660           0.2416
# 2        1709.0           0.14440            0.42450           0.4504
# 3         567.7           0.20980            0.86630           0.6869
# 4        1575.0           0.13740            0.20500           0.4000
# ..          ...               ...                ...              ...
# 564      2027.0           0.14100            0.21130           0.4107
# 565      1731.0           0.11660            0.19220           0.3215
# 566      1124.0           0.11390            0.30940           0.3403
# 567      1821.0           0.16500            0.86810           0.9387
# 568       268.6           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier
model= RandomForestClassifier()
model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
model.fit(x_train,y_train);

# %%
x_train
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 226  88147101        10.44         15.46           66.62      329.6
# 89     861598        14.64         15.24           95.77      651.9
# 367   9011495        12.21         18.02           78.31      458.4
# 17   84862001        16.13         20.68          108.10      798.8
# 27     852781        18.61         20.25          122.10     1094.0
# ..        ...          ...           ...             ...        ...
# 297    892189        11.76         18.14           75.00      431.1
# 541    921386        14.47         24.99           95.81      656.4
# 276   8911230        11.33         14.16           71.79      396.6
# 142    869218        11.43         17.31           73.66      398.0
# 474    911391        10.88         15.62           70.41      358.9
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 226          0.10530           0.07722        0.006643             0.012160
# 89           0.11320           0.13390        0.099660             0.070640
# 367          0.09231           0.07175        0.043920             0.020270
# 17           0.11700           0.20220        0.172200             0.102800
# 27           0.09440           0.10660        0.149000             0.077310
# ..               ...               ...             ...                  ...
# 297          0.09968           0.05914        0.026850             0.035150
# 541          0.08837           0.12300        0.100900             0.038900
# 276          0.09379           0.03872        0.001487             0.003333
# 142          0.10920           0.09486        0.020310             0.018610
# 474          0.10070           0.10690        0.051150             0.015710
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 226         0.1788  ...         11.52          19.80            73.47
# 89          0.2116  ...         16.34          18.24           109.40
# 367         0.1695  ...         14.29          24.04            93.85
# 17          0.2164  ...         20.96          31.48           136.80
# 27          0.1697  ...         21.31          27.26           139.90
# ..             ...  ...           ...            ...              ...
# 297         0.1619  ...         13.36          23.39            85.10
# 541         0.1872  ...         16.22          31.73           113.50
# 276         0.1954  ...         12.20          18.99            77.37
# 142         0.1645  ...         12.78          26.76            82.66
# 474         0.1861  ...         11.94          19.35            80.78
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 226       395.4            0.1341            0.11530         0.026390
# 89        803.6            0.1277            0.30890         0.260400
# 367       624.6            0.1368            0.21700         0.241300
# 17       1315.0            0.1789            0.42330         0.478400
# 27       1403.0            0.1338            0.21170         0.344600
# ..          ...               ...                ...              ...
# 297       553.6            0.1137            0.07974         0.061200
# 541       808.9            0.1340            0.42020         0.404000
# 276       458.0            0.1259            0.07348         0.004955
# 142       503.0            0.1413            0.17920         0.077080
# 474       433.1            0.1332            0.38980         0.336500
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 226               0.04464          0.2615                  0.08269
# 89                0.13970          0.3151                  0.08473
# 367               0.08829          0.3218                  0.07470
# 17                0.20730          0.3706                  0.11420
# 27                0.14900          0.2341                  0.07421
# ..                    ...             ...                      ...
# 297               0.07160          0.1978                  0.06915
# 541               0.12050          0.3187                  0.10230
# 276               0.01111          0.2758                  0.06386
# 142               0.06402          0.2584                  0.08096
# 474               0.07966          0.2581                  0.10800
#
# [455 rows x 31 columns]

# %%
y_preds=model.predict(x_test)
y_preds
# Out:
# array(['M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'M', 'B', 'M', 'M',
#        'M', 'B', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'M', 'M', 'B',
#        'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'M', 'M',
#        'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'M', 'B',
#        'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'M'], dtype=object)

# %%
y_test
# Out:
# 535    M
# 475    B
# 556    B
# 118    M
# 130    B
#       ..
# 194    M
# 282    M
# 96     B
# 391    B
# 254    M
# Name: diagnosis, Length: 114, dtype: object

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
print(classification_report(y_test,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            B       1.00      1.00      1.00        67
#            M       1.00      1.00      1.00        47
#
#     accuracy                           1.00       114
#    macro avg       1.00      1.00      1.00       114
# weighted avg       1.00      1.00      1.00       114

# %%
confusion_matrix(y_test,y_preds)
# Out:
# array([[67,  0],
#        [ 0, 47]], dtype=int64)

# %%
accuracy_score(y_test,y_preds)
# Out:
# 1.0

# %%
np.random.seed(69)
for i in range (10,100,10):
  print(f"trying model with {i} estimators")
  model=RandomForestClassifier(n_estimators=i).fit(x_train,y_train)
  percentage=model.score(x_test,y_test)
  print(f"model accuracy on test set:{percentage}")
  print("")
# Out:
# trying model with 10 estimators
# model accuracy on test set:0.9824561403508771
#
# trying model with 20 estimators
# model accuracy on test set:0.9912280701754386
#
# trying model with 30 estimators
# model accuracy on test set:0.9912280701754386
#
# trying model with 40 estimators
# model accuracy on test set:0.9912280701754386
#
# trying model with 50 estimators
# model accuracy on test set:0.9912280701754386
#
# trying model with 60 estimators
# model accuracy on test set:0.9912280701754386
#
# trying model with 70 estimators
# model accuracy on test set:0.9912280701754386
#
# trying model with 80 estimators
# model accuracy on test set:0.9912280701754386
#
# trying model with 90 estimators
# model accuracy on test set:0.9912280701754386
